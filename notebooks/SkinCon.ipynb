# %%
import torch
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Malika/datasets.zip /content/
# !unzip -q /content/datasets.zip -d /content/

# %%
# !cp -r /content/drive/MyDrive/Malika/models /content/
# !cp -r /content/drive/MyDrive/Malika/scripts /content/
# !cp -r /content/drive/MyDrive/Malika/evaluate.py /content/
# !cp -r /content/drive/MyDrive/Malika/train.py /content/
# !cp -r /content/drive/MyDrive/Malika/dataset_loader.py /content/datasets

# %%
# !python scripts/new_preprocess.py
# Out:
# ✅ Filtered dataset saved to: datasets/Derm7pt/Derm7pt_filtered.csv
# 📂 Filtered dataset: 827 images remain after filtering.
# 🔹 Train: 346, Validation: 161, Test: 320
# ✅ Dataset 'Derm7pt' processing complete!
#
# ✅ Found 2013 images in datasets/Derm7pt/images
# ✅ Concept dataset 'Derm7pt_concepts' created successfully!
# ✅ Filtered dataset saved to: datasets/SkinCon/SkinCon_filtered.csv
# 📂 Filtered dataset: 3221 images remain after filtering.
# 🔹 Train: 2254, Validation: 483, Test: 484
# ✅ Dataset 'SkinCon' processing complete!
#
# ✅ Found 16577 images in datasets/SkinCon/images
# ✅ Concept dataset 'SkinCon_concepts' created successfully!

# %%
# !python train.py --dataset SkinCon --concept_dataset SkinCon_concepts --model resnet50 --use_caw --batch_size 64 --epochs 100 --lr 2e-3 --output_dir ./checkpoints
# Out:
# 📂 Train Dataset Size: 2583
# 📂 Validation Dataset Size: 553
# 📂 Test Dataset Size: 554
# 📂 Concept Dataset Size: 9490
# 🔍 Dataset Type: <class 'torch.utils.data.dataset.Subset'>
# 🔍 Dataset Attributes: ['__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getitems__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_is_protocol', 'dataset', 'indices']
# 🚀 Initializing resnet50 with CAW: True
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 177MB/s]
# 🔄 Replacing BN layer 16 with CAW
# ...

# %%
# !python evaluate.py --dataset SkinCon --model resnet50 --use_caw --batch_size 64 --output_dir checkpoints
# Out:
# 🔹 Using device: cuda
# 📂 Train Dataset Size: 2583
# 📂 Validation Dataset Size: 553
# 📂 Test Dataset Size: 554
# 📂 Test Dataset Size: 9
# 🔄 Evaluating Model 0 from: checkpoints/SkinCon_resnet50_seed_0_best.pth
# 🔍 Loading model from: checkpoints/SkinCon_resnet50_seed_0_best.pth
# ...
